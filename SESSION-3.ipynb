# %% [markdown]
# # SESSION - 3.

# %% [markdown]
# # TASK - 1.

# %%
age = int(input("enter your age :"))
print("your age is :",age)
print("the type of your age is :",type(age))

height = float(input("enter your height in cm :"))
print("your height is in cm :",height)
print("the type of your height is :",type(height))

name = input("enter your name :")
print("your name is :",name)
print("the type of your name is :",type(name))

spotify_account = True
print("the spotify account is :",spotify_account)
print("the type of spotify_acoount is :",type(spotify_account))
# Out:
# your age is : 22
# the type of your age is : <class 'int'>
# your height is in cm : 6.7
# the type of your height is : <class 'float'>
# your name is : aryan
# the type of your name is : <class 'str'>
# the spotify account is : True
# the type of spotify_acoount is : <class 'bool'>

# %% [markdown]
# # TASK - 2.

# %%
total_cart_amount = ["199.99","49","350.75"]
print(total_cart_amount)

a = total_cart_amount[0]
b = float(a)
print("the first float number is :",b)
print(type(b))

a = total_cart_amount[1]
c = float(a)
print("the second float number is :",c)
print(type(c))


a = total_cart_amount[2]
d = float(a)
print("the third float number is :",d)
print(type(d))

the_sum = b + c + d
e = the_sum
print("the sum of this float three number is :",e)
print(type(e))
# Out:
# ['199.99', '49', '350.75']
# the first float number is : 199.99
# <class 'float'>
# the second float number is : 49.0
# <class 'float'>
# the third float number is : 350.75
# <class 'float'>
# the sum of this float three number is : 599.74
# <class 'float'>

# %% [markdown]
# # TASK - 3.

# %%
cricket_score = input("enter user cricket score :")
print("enter the cricket score is as string :",cricket_score)
print(type(cricket_score))
a = int(cricket_score)
print("the cricket score as data type integer :",a)
print(type(a))

if a >= 50:
    print("half century.")
else:
    print("keep going.")
# Out:
# enter the cricket score is as string : 22
# <class 'str'>
# the cricket score as data type integer : 22
# <class 'int'>
# keep going.

# %% [markdown]
# # TASK - 4.

# %%
is_premium = "True"
print("the value of is premium :",is_premium)
print("the data type of is premium :",type(is_premium))

a = bool(is_premium)
print("the value of is premium :",a)
print("the data type of is premium :",type(a))
# Out:
# the value of is premium : True
# the data type of is premium : <class 'str'>
# the value of is premium : True
# the data type of is premium : <class 'bool'>
