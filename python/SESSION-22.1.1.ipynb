# %% [markdown]
# # SESSION - 22.1.1.

# %% [markdown]
# # QUESTION - 1.

# %%
import requests

session = requests.Session()

url = "https://www.flipkart.com/account/orders"

response1 = session.get(url)
response2 = session.get(url)

print("First Request Status:", response1.status_code)
print("Second Request Status:", response2.status_code)

print("Cookies:", session.cookies)
# Out:
# First Request Status: 403
# Second Request Status: 403
# Cookies: <RequestsCookieJar[]>

# %% [markdown]
# # QUESTION - 2.

# %%
import requests

api_key = "YOUR_REAL_API_KEY"

url = "https://api.openweathermap.org/data/2.5/weather"

params = {
    "q": "Ahmedabad",
    "appid": api_key,
    "units": "metric"
}

response = requests.get(url, params=params)

print(response.status_code)
print(response.json())
# Out:
# 401
# {'cod': 401, 'message': 'Invalid API key. Please see https://openweathermap.org/faq#error401 for more info.'}

# %% [markdown]
# # QUESTION - 3.

# %%
# !pip install httpx
# Out:
# Collecting httpx
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting anyio (from httpx)
#   Downloading anyio-4.14.2-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: certifi in c:\users\shaha\onedrive\desktop\python 11-7\.venv\lib\site-packages (from httpx) (2026.7.22)
# Collecting httpcore==1.* (from httpx)
#   Downloading httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: idna in c:\users\shaha\onedrive\desktop\python 11-7\.venv\lib\site-packages (from httpx) (3.19)
# Collecting h11>=0.16 (from httpcore==1.*->httpx)
#   Downloading h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
# Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading anyio-4.14.2-py3-none-any.whl (125 kB)
# Installing collected packages: h11, anyio, httpcore, httpx
#
#    ---------------------------------------- 0/4 [h11]
#    ---------------------------------------- 0/4 [h11]
#    ---------------------------------------- 0/4 [h11]
#    ---------- ----------------------------- 1/4 [anyio]
#    ---------- ----------------------------- 1/4 [anyio]
#    ---------- ----------------------------- 1/4 [anyio]
#    ---------- ----------------------------- 1/4 [anyio]
#    ---------- ----------------------------- 1/4 [anyio]
#    ---------- ----------------------------- 1/4 [anyio]
#    ---------- ----------------------------- 1/4 [anyio]
#    ---------- ----------------------------- 1/4 [anyio]
#    -------------------- ------------------- 2/4 [httpcore]
#    -------------------- ------------------- 2/4 [httpcore]
#    -------------------- ------------------- 2/4 [httpcore]
#    -------------------- ------------------- 2/4 [httpcore]
#    -------------------- ------------------- 2/4 [httpcore]
#    -------------------- ------------------- 2/4 [httpcore]
#    -------------------- ------------------- 2/4 [httpcore]
#    ------------------------------ --------- 3/4 [httpx]
#    ------------------------------ --------- 3/4 [httpx]
#    ------------------------------ --------- 3/4 [httpx]
#    ------------------------------ --------- 3/4 [httpx]
#    ------------------------------ --------- 3/4 [httpx]
#    ------------------------------ --------- 3/4 [httpx]
#    ---------------------------------------- 4/4 [httpx]
#
# Successfully installed anyio-4.14.2 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1
# [notice] A new release of pip is available: 25.3 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import httpx

print("httpx installed successfully")
# Out:
# httpx installed successfully

# %%
import asyncio
import httpx

async def fetch_song():
    url = "https://jsonplaceholder.typicode.com/posts/1"

    async with httpx.AsyncClient() as client:
        response = await client.get(url)
        return response.json()


async def fetch_movie():
    url = "https://jsonplaceholder.typicode.com/posts/2"

    async with httpx.AsyncClient() as client:
        response = await client.get(url)
        return response.json()


async def main():

    song, movie = await asyncio.gather(
        fetch_song(),
        fetch_movie()
    )

    print("Trending Song:", song)
    print("Trending Movie:", movie)


await main()
# Out:
# Trending Song: {'userId': 1, 'id': 1, 'title': 'sunt aut facere repellat provident occaecati excepturi optio reprehenderit', 'body': 'quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto'}
# Trending Movie: {'userId': 1, 'id': 2, 'title': 'qui est esse', 'body': 'est rerum tempore vitae\nsequi sint nihil reprehenderit dolor beatae ea dolores neque\nfugiat blanditiis voluptate porro vel nihil molestiae ut reiciendis\nqui aperiam non debitis possimus qui neque nisi nulla'}

# %% [markdown]
# # QUESTION - 4.

# %%
import requests

def get_user_profile():

    url = "https://jsonplaceholder.typicode.com/users/1"

    token = "fake_token_123"

    headers = {
        "Authorization": "Bearer " + token
    }

    response = requests.get(url, headers=headers)

    data = response.json()

    print("User Name:", data["name"])


get_user_profile()
# Out:
# User Name: Leanne Graham

# %% [markdown]
# # QUESTION - 5.

# %%
import urllib.parse

client_id = "YOUR_CLIENT_ID"

redirect_uri = "http://localhost:8000/callback"

scope = "user-read-private user-read-email"

params = {
    "client_id": client_id,
    "response_type": "code",
    "redirect_uri": redirect_uri,
    "scope": scope
}

url = "https://accounts.spotify.com/authorize?" + urllib.parse.urlencode(params)

print("Open this URL:")
print(url)
# Out:
# Open this URL:
# https://accounts.spotify.com/authorize?client_id=YOUR_CLIENT_ID&response_type=code&redirect_uri=http%3A%2F%2Flocalhost%3A8000%2Fcallback&scope=user-read-private+user-read-email
