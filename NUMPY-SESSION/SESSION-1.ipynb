# %% [markdown]
# # SESSION - 1.

# %% [markdown]
# # QUESTION - 1.

# %%
# !pip install numpy

# %%
import numpy as np

# %% [markdown]
# # QUESTION - 2.

# %%
a = [1200, 15000, 67000, 340000, 1250000]
print("the list is :",a)
print("the type of this list is :",type(a))

followers = a
followers = np.array([1200, 15000, 67000, 340000, 1250000])
followers
print("the shape of this array is :",np.shape(followers))
print("the dimensions of this array is :",np.ndim(followers))
print("the data type of every element in this array is :",followers.dtype)
# Out:
# the list is : [1200, 15000, 67000, 340000, 1250000]
# the type of this list is : <class 'list'>
# the shape of this array is : (5,)
# the dimensions of this array is : 1
# the data type of every element in this array is : int64

# %% [markdown]
# # QUESTION - 3.

# %%
a = np.arange(101,111)
print("the array is :",a)
print("the total element in this array is :",np.size(a))
# Out:
# the array is : [101 102 103 104 105 106 107 108 109 110]
# the total element in this array is : 10

# %% [markdown]
# # QUESTION - 4.

# %%
np.eye(3,3)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %% [markdown]
# Important: np.eye(3) → 3 × 3 identity matrix banata hai.
# Diagonal = 1
# Baaki values = 0

# %% [markdown]
# # QUESTION - 5.

# %%
x = [45, 67, 120, 89, 54]
print("the list is :",x)
print("the type of this list is :",type(x))

y = x
y = np.array(x)
print("the array is :",y)

t = y.itemsize
print("the item size of this array is :",t)
# Out:
# the list is : [45, 67, 120, 89, 54]
# the type of this list is : <class 'list'>
# the array is : [ 45  67 120  89  54]
# the item size of this array is : 8

# %% [markdown]
# 8 bytes = har ek score ki memory size.
