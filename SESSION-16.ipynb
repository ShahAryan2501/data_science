# %% [markdown]
# # SESSION - 16.

# %% [markdown]
# # QUESTION - 1.

# %%
favorite_food_delivery_apps = ["zomato","blinkit","zepto","swiggy","instamart"]
a = iter(favorite_food_delivery_apps)

# %%
for i in a:
    print(i)
# Out:
# zomato
# blinkit
# zepto
# swiggy
# instamart

# %% [markdown]
# # QUESTION - 2.

# %%
def playlist_generator(songs):
    a = iter(playlist_generator(songs))
    for song in songs:
        print(song)
        yield songs

# %%
a = ["Believer", "Shape of You", "Perfect", "Levitating"]
for i,name in enumerate (a,start=1):
    print(i,"- the song name is:",name)
# Out:
# 1 - the song name is: Believer
# 2 - the song name is: Shape of You
# 3 - the song name is: Perfect
# 4 - the song name is: Levitating

# %% [markdown]
# # QUESTION - 3.

# %%
food_items = ['Pizza', 'Burger', 'Fries', 'Coke']
for i,names in enumerate(food_items,start=1):
    print("item",i,":",names)
# Out:
# item 1 : Pizza
# item 2 : Burger
# item 3 : Fries
# item 4 : Coke

# %% [markdown]
# # QUESTION - 4.

# %%
ipl_team = ["mumbai indians"]
ipl_score = [18]

for a,b in zip(ipl_team,ipl_score):
    print(f"the team name is {a}, his ipl score is {b}.")
# Out:
# the team name is mumbai indians, his ipl score is 18.

# %% [markdown]
# # QUESTION - 5.

# %%
def order_id():
    for i in range (101,106):
        yield i

a = order_id()

# %%
for w in (a):
    print("order_id :",w)
# Out:
# order_id : 101
# order_id : 102
# order_id : 103
# order_id : 104
# order_id : 105
