# %% [markdown]
# # SESSION - 5.

# %% [markdown]
# # TASK - 1.

# %%
playlist_ids = [101,102,103,104,105]
spotify_playlist = playlist_ids
print("the 5 song ids is :",spotify_playlist)
print(type(spotify_playlist))
# Out:
# the 5 song ids is : [101, 102, 103, 104, 105]
# <class 'list'>

# %% [markdown]
# # TASK - 2.

# %%
playlist_ids = [101,102,103,104,105]
print("the playlist ids is :",playlist_ids)
playlist_ids.append(106)
print("the only one ids add in this list :",playlist_ids)

playlist_ids.extend([107,108])
print("the multiple ids add in this list :",playlist_ids)
# Out:
# the playlist ids is : [101, 102, 103, 104, 105]
# the only one ids add in this list : [101, 102, 103, 104, 105, 106]
# the multiple ids add in this list : [101, 102, 103, 104, 105, 106, 107, 108]

# %% [markdown]
# # TASK - 3.

# %%
playlist_ids = [101,102,103,104,105]
print("the playlist ids is :",playlist_ids)

a = playlist_ids.pop(4)
print("the removerd last song id from this list :",a)

print("the updated song id is :",playlist_ids)
# Out:
# the playlist ids is : [101, 102, 103, 104, 105]
# the removerd last song id from this list : 105
# the updated song id is : [101, 102, 103, 104]

# %% [markdown]
# # TASK - 4.

# %%
insta_filters = ("clarendon","juno","lark","gingham")
print(insta_filters)

insta_filters[0] = "luNdwig"
print(insta_filters)
# Out:
# ('clarendon', 'juno', 'lark', 'gingham')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 4
#       1 insta_filters = ("clarendon","juno","lark","gingham")
#       2 print(insta_filters)
# ----> 4 insta_filters[0] = "ludwig"
#       5 print(insta_filters)
#
# TypeError: 'tuple' object does not support item assignment

# %%
# tuples are inmmutable. so, when we make any tuple and print we ha ve no chages in tuple like update,delete,add,remove.

# %% [markdown]
# # TASK - 5.

# %%
# Ek aisa data jo badlta rehta hai isme ham List method ka use kar sakte hain becuase
# list mei ak baar create ho jane ke baad bhi hum update,delete,add,remove kar sakte hai.

zomato_orders = ["pizza","puff","burger","maggi","sandwich","icecream"]
print("the zomato orders is :",zomato_orders)

zomato_orders.append("cold drink")
print("the new zomato orders is :",zomato_orders)

zomato_orders.pop(4)
print("the updated zomato orders is :",zomato_orders)

# phir ak aur scribt banai jaise IPL teams names jo fix hai and wo ek bar create ho jane ke baad chnage
#  nahi karna hai ab iske ;liye hum tuble ka user kar sakte hai becuase tuble mei ak baar item add karne ke baad and tuple ko print 
# karne ke baad hum usme change nahi kar sakte hai means tuple inmmutable hai.

ipl_teams = ("csk","rcb","rr","mi","lsg","gt")
print("the name of ipl team is :",ipl_teams)

# abu hum ak baar tuble banne ke baad hum usme ab chnage nahi kar sakte hai.
# Out:
# the zomato orders is : ['pizza', 'puff', 'burger', 'maggi', 'sandwich', 'icecream']
# the new zomato orders is : ['pizza', 'puff', 'burger', 'maggi', 'sandwich', 'icecream', 'cold drink']
# the updated zomato orders is : ['pizza', 'puff', 'burger', 'maggi', 'icecream', 'cold drink']
# the name of ipl temas is : ('csk', 'rcb', 'rr', 'mi', 'lsg', 'gt')
