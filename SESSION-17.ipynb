# %% [markdown]
# # SESSION - 17.

# %% [markdown]
# # QUESTION - 1.

# %%
from math import sqrt
number = int(input("enter the number :"))
print("the user enter number is :",number)

print(f"square of int {number} is :",sqrt(number))
# Out:
# the user enter number is : 36
# square of int 36 is : 6.0

# %% [markdown]
# # QUESTION - 2.

# %%
import os
folder_name = "mydownloads"

path = os.mkdir(folder_name)

new_path = os.path.abspath(folder_name)

print("the folder creates successfully.")
print("the right path is :",new_path)
# Out:
# the folder creates successfully.
# the right path is : c:\Users\shaha\OneDrive\Desktop\PYTHON 11-7\mydownloads

# %% [markdown]
# # QUESTION - 3.

# %%
from datetime import datetime

new_datetime = datetime.now()

print(new_datetime.strftime("Today Date Is : %d-%m-%y \nRight Time Is : %H-%M-AM"))
# Out:
# Today Date Is : 04-08-26
# Right Time Is : 09-47-AM
