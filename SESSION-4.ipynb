# %% [markdown]
# # SESSION - 4.

# %% [markdown]
# # TASK - 1.

# %%
flipkart = "Flipkart-Sale2024"
a = flipkart.lower()
print("the lower case of this cell is :",a)
b = a.replace("-"," ")
print("this cell with space :",b)
# Out:
# the lower case of this cell is : flipkart-sale2024
# this cell with space : flipkart sale2024

# %% [markdown]
# # TASK - 2.

# %%
a = " OnePlus Nord-CE 3 "
print("the product name is :",a)
b = a.strip()
print("after romove extra space :",b)

c = b.upper()
print("covert into upper case :",c)

d = c.replace("-",":")
print("after replace this variable :",d)
# Out:
# the product name is :  OnePlus Nord-CE 3
# after romove extra space : OnePlus Nord-CE 3
# covert into upper case : ONEPLUS NORD-CE 3
# after replace this variable : ONEPLUS NORD:CE 3

# %% [markdown]
# # TASK - 3.

# %%
split_product_code = "ZOMATO-FOOD-2024"
b = split_product_code.split("-")
print(b)
# Out:
# ['ZOMATO', 'FOOD', '2024']

# %% [markdown]
# # TASK - 4.

# %%
a = "Spotify_Premium_Offer"
print(len(a))
print(a)

b = a[8:15]
print("the only word is print :",b)
# Out:
# 21
# Spotify_Premium_Offer
# the only word is print : Premium

# %% [markdown]
# # TASK - 5.

# %%
product = "Myntra Shirt"
price = 799.5
print(f"Deal: {product} is available at ₹{price}0 only!")
# Out:
# Deal: Myntra Shirt is available at ₹799.50 only!
