# %% [markdown]
# # SESSION - 1.

# %% [markdown]
# # TASK - 1.

# %% [markdown]
# # TASK - 2.

# %%
a = input("enter your name :")
print("my name is :",a)
b = input("enter your favorite app like zomato or instagram :")
print("my favorite app is :",b)
# Out:
# my name is : aryan
# my favorite app is : zomato

# %% [markdown]
# # TASK - 3.

# %%
print("Welcome to Data Science with Python!")
# Out:
# Welcome to Data Science with Python!
