# %% [markdown]
# # SESSION - 6.

# %% [markdown]
# # TASK - 1.

# %%
insta_followers = {
    "viratkohli" : 22,
    "ms dhoni" : 28,
    "akshay kumar" : 30,
    "aryan" : 127,
    "harsh" : 122
}

print(insta_followers)
print(type(insta_followers))
# Out:
# {'viratkohli': 22, 'ms dhoni': 28, 'akshay kumar': 30, 'aryan': 127, 'harsh': 122}
# <class 'dict'>

# %% [markdown]
# # TASK - 2.

# %%
insta_followers = {
    "viratkohli" : 22,
    "ms dhoni" : 28,
    "akshay kumar" : 30,
    "aryan" : 127,
    "harsh" : 122
}

insta_followers.update({"salman khan":20})
print(insta_followers)

a =insta_followers["viratkohli"] = 29
print("the updated insta influencer and update virat kolhi insta followers is :",a)

del insta_followers["harsh"]
print("the updated insta influencers is :",insta_followers)

print(insta_followers)
# Out:
# {'viratkohli': 22, 'ms dhoni': 28, 'akshay kumar': 30, 'aryan': 127, 'harsh': 122, 'salman khan': 20}
# the updated insta influencer and update virat kolhi insta followers is : 29
# the updated insta influencers is : {'viratkohli': 29, 'ms dhoni': 28, 'akshay kumar': 30, 'aryan': 127, 'salman khan': 20}
# {'viratkohli': 29, 'ms dhoni': 28, 'akshay kumar': 30, 'aryan': 127, 'salman khan': 20}

# %% [markdown]
# # TASK - 3.

# %%
food_prices = {
    "pizza" : 250,
    "maggi" : 120,
    "ice cream" : 210,
    "burger" : 80,
    "pasta" : 220
}

expensive_food = {}

for item in food_prices:
    if food_prices[item] > 200:
        expensive_food[item] = food_prices[item]

print(expensive_food)
# Out:
# {'pizza': 250, 'ice cream': 210, 'pasta': 220}

# %% [markdown]
# # TASK - 4.

# %%
flipkart_users = {"ok","if","else","why","because"}
myntra_users = {"ok","df","ds","else","why"}

a= flipkart_users.intersection(myntra_users)
print(a)
# Out:
# {'else', 'why', 'ok'}

# %% [markdown]
# # TASK - 5.

# %%
spotify_playlist1 = {"aryan","harsh","kk menon","arijit singh","sherya ghosal"}
spotify_playlist2 ={"aryan","akshay kumar","arijit singh","kk menon","vishal"}

spotify_playlist = spotify_playlist1.union(spotify_playlist2)
print(spotify_playlist)
# Out:
# {'sherya ghosal', 'vishal', 'akshay kumar', 'harsh', 'arijit singh', 'kk menon', 'aryan'}

# %% [markdown]
# # SESSION - 6.

# %% [markdown]
# # TASK - 1.

# %%
insta_followers = {
    "virat kohli" : 22,
    "ms dhoni" : 30,
    "akshay kumar" : 120,
    "salman khan" : 100,
    "aryan" : 112

}
print(insta_followers)
# Out:
# {'virat kohli': 22, 'ms dhoni': 30, 'akshay kumar': 120, 'salman khan': 100, 'aryan': 112}

# %% [markdown]
# # TASK - 2.

# %%
insta_followers = {
    "virat kohli" : 22,
    "ms dhoni" : 30,
    "akshay kumar" : 120,
    "salman khan" : 100,
    "aryan" : 112

}

print("the origintal dictionary is :",insta_followers)

# the new insta influencer add in dictionary.
insta_followers["harsh"] = 112
print("the new insta influencer add in this dictionary :",insta_followers)

# updare one influencer follwers count.
insta_followers["virat kohli"] = 70
print("the updated dictionary is :",insta_followers)

# delete one influencer from dictionary.
insta_followers.pop("salman khan")
print("the updated dictionary is :",insta_followers)
# Out:
# the origintal dictionary is : {'virat kohli': 22, 'ms dhoni': 30, 'akshay kumar': 120, 'salman khan': 100, 'aryan': 112}
# the new insta influencer add in this dictionary : {'virat kohli': 22, 'ms dhoni': 30, 'akshay kumar': 120, 'salman khan': 100, 'aryan': 112, 'harsh': 112}
# the updated dictionary is : {'virat kohli': 70, 'ms dhoni': 30, 'akshay kumar': 120, 'salman khan': 100, 'aryan': 112, 'harsh': 112}
# the updated dictionary is : {'virat kohli': 70, 'ms dhoni': 30, 'akshay kumar': 120, 'aryan': 112, 'harsh': 112}

# %% [markdown]
# # TASK - 3.

# %%
food_prices = {
    "pizza" : 220,
    "maggi" : 250,
    "burger" : 120,
    "icecream" : 100,
    "sandwich" : 230
}


expensive_food = {}

for item in food_prices:
    if food_prices[item] > 200:
        expensive_food[item] = food_prices[item]

print(expensive_food)
# Out:
# {'pizza': 220, 'maggi': 250, 'sandwich': 230}

# %% [markdown]
# # TASK - 4.

# %%
flipkart_users = {"ok","why","because","if","else"}
myntra_users = {"ok","because","task","session","open"}

a =flipkart_users.intersection(myntra_users)

print("the unique user names in both sets is :",a)
# Out:
# the unique user names in both sets is : {'because', 'ok'}

# %% [markdown]
# # TASK - 5.

# %%
spotify_playlist1 = {"arijit singh","vishal","mithoon","armaan malik","shreya ghosal"}
spotify_playlist2 = {"salman khan","jenifer","arijit singh","shreya ghosal"}

spotify_playlist = spotify_playlist1.union(spotify_playlist2)
print("the unqiues artists in both sets is :",spotify_playlist)
# Out:
# the unqiues artists in both sets is : {'arijit singh', 'shreya ghosal', 'armaan malik', 'vishal', 'mithoon', 'jenifer', 'salman khan'}
