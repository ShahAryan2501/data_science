# %% [markdown]
# # SESSION - 8.

# %% [markdown]
# # QUESTION - 1.

# %%
food_delivery_apps = ["zomato","swiggy","zepto","blinkit","repido"]
for i, name in enumerate(food_delivery_apps,start=1):
    print(i,":",name)
# Out:
# 1 : zomato
# 2 : swiggy
# 3 : zepto
# 4 : blinkit
# 5 : repido

# %% [markdown]
# # QUESTION - 2.

# %%
steps = [7000,8000,6000,5000,11000,12000,2000]
for i in steps:
    if i > 10000:
        break
print("the first time completed 10000 is :",i)
# Out:
# the first time completed 10000 is : 11000

# %% [markdown]
# # QUESTION - 3.

# %%
ipl_team = ["csk","rr","rcb","pbks","chennai","pujabs","mumbaiindians","gujarat"]
count = 0
for team in ipl_team:
    if len(team) <= 6:
        continue
    count = count + 1

    print("the total team to less than 6 letter :",count)
    print("the team name is in this list to less than 6 letter :",team)
# Out:
# the total team to less than 6 letter : 1
# the team name is in this list to less than 6 letter : chennai
# the total team to less than 6 letter : 2
# the team name is in this list to less than 6 letter : mumbaiindians
# the total team to less than 6 letter : 3
# the team name is in this list to less than 6 letter : gujarat

# %% [markdown]
# # QUESTION - 4.

# %%
spotify_playlist = ["210 seconds","220 seconds","230 seconds","240 seconds","250 seconds"]
for i, song in enumerate(spotify_playlist,start=1):
    print("song",i,":",song)
# Out:
# song 1 : 210 seconds
# song 2 : 220 seconds
# song 3 : 230 seconds
# song 4 : 240 seconds
# song 5 : 250 seconds

# %% [markdown]
# # QUESTION - 5.

# %%
def flipcart_cart(prices):
    total = 0
    for i in prices:
        if i == 0:
            continue
        total = total + i
        if total > 2000:
            break
    print("the list at stoppe at :",i)
    print("the total is :",total)

# %%
prices = [200,0,0,500,700,0,0,1000,2000]
flipcart_cart(prices)
# Out:
# the list at stoppe at : 1000
# the total is : 2400
