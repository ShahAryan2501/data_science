# %% [markdown]
# # SESSION - 2.

# %% [markdown]
# # TASK - 1.

# %%
item_price = 250
delivery_fee = 30
coupon_discount = 20
print(f"item_price : {item_price}\n delivery_fee : {delivery_fee}\n coupon_discount : {coupon_discount}")
# Out:
# item_price : 250
#  delivery_fee : 30
#  coupon_discount : 20

# %% [markdown]
# # TASK - 2.

# %%
flipkart_product = int(input("enter flipkart product price :"))
print("the flipkart product price is :",flipkart_product)

if flipkart_product >= 1000:
    print("So, user is epligible for a free delivery.")
else:
    print("Sorry,user is not eligible for a free delivery.")
# Out:
# the flipkart product price is : 990
# Sorry,user is not eligible for a free delivery.

# %% [markdown]
# # TASK - 3.

# %%
# single line comments

'''multi line comments'''

# %% [markdown]
# # TASK - 4.

# %%
team_name = input("enter ipl any one team name :")
print("the team name is :",team_name)

runs_scored = int(input("enter run socred by one team :"))
print(f"the run scored by {team_name} team is :",runs_scored)

overs_played = float(input("enter tthe overs played by one team :"))
print(f"the overs played by {team_name} team is :",overs_played)
# Out:
# the team name is : csk
# the run scored by csk team is : 272
# the overs played by csk this  is : 20.0
