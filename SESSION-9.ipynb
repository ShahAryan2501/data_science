# %% [markdown]
# # SESSION - 4.

# %% [markdown]
# # QUESTION - 1.

# %%
def calculate_final_price(price,discount_rate):
    discount = price * 10/100
    total_price = price - discount
    print("the discount for this product is :",discount)
    print("the price is after remove discount :",total_price)

# %%
calculate_final_price(1000,10)
# Out:
# the discount for this product is : 100.0
# the price is after remove discount : 900.0

# %% [markdown]
# # QUESTION - 2.

# %%
def get_delivery_charge(amount,city="ahmedabad"):
    if city == "ahmedabad":
        print("delivery charge is 0 rupees.")
    else:
        print("delivery charge apply 50.")

# %%
get_delivery_charge(200,"mumbai")
# Out:
# delivery charge is 0 rupees.
